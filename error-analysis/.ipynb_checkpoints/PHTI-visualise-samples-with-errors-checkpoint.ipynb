# %% [markdown]
# # 📘 PHTI (Pashto) Dataset — CRHV Error Analysis Notebook
# ### *CRHV: CER Ranking with Human Verification*
#
# This notebook analyzes results obtained from the
# **CRHV (CER Ranking with Human Verification)** framework across the  **val**,
# and **test** splits of the **Muharaf dataset**.
#
# ---
#
# ## 🧮 1. Count Error Categories for Each Split
#
# To compute how many samples belong to each error category, run:
#
# ```python
# %run error_counts.py phti/hitl_labels_log_test.csv
# ```
#
# Change the path based on the dataset split you want to analyze:
#
# - `phti/hitl_labels_log_val.csv`
# - `phti/hitl_labels_log_test.csv`
#
# The script prints:
#
# - The list of error categories found in the `Label` column
# - The number of samples per category
# - The total number of labeled samples (excluding empty labels and "Valid but hard")
#
# ---
#
# ## 🖼️ 2. Visualize Samples by Error Category
#
# To visualize example images from each error category, run:
#
# ```python
# %run visualize_hitl_by_label.py khatt/hitl_labels_log_test.csv --split test --max-per-group 5
# ```
#
# Where:
# - split selects the dataset split (val, test)
# - max-per-group defines how many images to show per category
#
# Examples:
# ```python
# %run visualize_hitl_by_label.py phti/hitl_labels_log_val.csv   --split val   --max-per-group 8
# %run visualize_hitl_by_label.py phti/hitl_labels_log_test.csv  --split test  --max-per-group 5
#
# ```

# %% [markdown]
# # Test Split

# %%
# %run error_counts.py phti/hitl_labels_log_test.csv
# Out:
# Processing file: phti/hitl_labels_log_test.csv
#
# Counts per error category (using REAL 'Label' column):
#
# Orientation error: 20
# Segmentation error: 4
# Wrong transcription: 48
#
# Total samples: 72
#
# --------------------------------------------------

# %%
# %run visualize_hitl_by_label.py phti/hitl_labels_log_test.csv   --split train   --max-per-group 10
# Out:
# === Visualizing HITL labels ===
# CSV:          phti/hitl_labels_log_test.csv
# Split:        train
# Base img dir: ../data/muharaf_prepared_resized
# Max/group:    10
# ...
#
# Total labeled samples (excluding 'valid but hard'): 72
# Error categories: ['Orientation error', 'Segmentation error', 'Wrong transcription']
# <h3>Error type: Orientation error</h3>
# <p>Showing 10 example(s).</p>
#         <table style="width:100%; border-collapse: collapse; margin-bottom: 2em;">
#           <thead>
#             <tr>
#               <th style="text-align:left;   border-bottom:1px solid #ccc;">ImageID</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">CER</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Ground Truth</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Prediction</th>
#             </tr>
#           </thead>
#           <tbody>
#
#             <tr>
# ...

# %% [markdown]
# # __________________________________________________
# # Val Split
# # __________________________________________________

# %%
# %run error_counts.py phti/hitl_labels_log_val.csv
# Out:
# Processing file: phti/hitl_labels_log_val.csv
#
# Counts per error category (using REAL 'Label' column):
#
# Orientation error: 15
# Segmentation error: 2
# Wrong transcription: 59
#
# Total samples: 76
#
# --------------------------------------------------

# %%
# %run visualize_hitl_by_label.py phti/hitl_labels_log_val.csv --split test --max-per-group 5
# Out:
# === Visualizing HITL labels ===
# CSV:          phti/hitl_labels_log_val.csv
# Split:        test
# Base img dir: ../data/muharaf_prepared_resized
# Max/group:    5
# ...
#
# Total labeled samples (excluding 'valid but hard'): 76
# Error categories: ['Orientation error', 'Segmentation error', 'Wrong transcription']
# <h3>Error type: Orientation error</h3>
# <p>Showing 5 example(s).</p>
#         <table style="width:100%; border-collapse: collapse; margin-bottom: 2em;">
#           <thead>
#             <tr>
#               <th style="text-align:left;   border-bottom:1px solid #ccc;">ImageID</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">CER</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Ground Truth</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Prediction</th>
#             </tr>
#           </thead>
#           <tbody>
#
#             <tr>
#               <td>PHTI-DM-F-0001-3</td>
# ...

# %% [markdown]
# # __________________________________________________
# # train Split
# # __________________________________________________

# %%
 # %run error_counts.py phti/hitl_labels_log_train.csv
# Out:
# Processing file: phti/hitl_labels_log_train.csv
#
# Counts per error category (using REAL 'Label' column):
#
# Orientation error: 98
# Segmentation error: 2
# Wrong transcription: 220
#
# Total samples: 320
#
# --------------------------------------------------

# %%
 # %run visualize_hitl_by_label.py phti/hitl_labels_log_train.csv --split train --max-per-group 5
# Out:
# === Visualizing HITL labels ===
# CSV:          phti/hitl_labels_log_train.csv
# Split:        train
# Base img dir: ../data/muharaf_prepared_resized
# Max/group:    5
# ...
#
# Total labeled samples (excluding 'valid but hard'): 320
# Error categories: ['Orientation error', 'Segmentation error', 'Wrong transcription']
# <h3>Error type: Orientation error</h3>
# <p>Showing 5 example(s).</p>
#         <table style="width:100%; border-collapse: collapse; margin-bottom: 2em;">
#           <thead>
#             <tr>
#               <th style="text-align:left;   border-bottom:1px solid #ccc;">ImageID</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">CER</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Ground Truth</th>
#               <th style="text-align:right;  border-bottom:1px solid #ccc;">Prediction</th>
#             </tr>
#           </thead>
#           <tbody>
#
#             <tr>
# ...
